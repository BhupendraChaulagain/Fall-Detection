# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fall1 = pd.read_csv('new_fall1.csv')
fall2 = pd.read_csv('new_fall2.csv')
fall3 = pd.read_csv('new_fall3.csv')
fall4 = pd.read_csv('new_fall4.csv')
fall5 = pd.read_csv('new_fall5.csv')
fall6 = pd.read_csv('new_fall6.csv')

# %%
df=pd.concat([fall1, fall2, fall3, fall4, fall5, fall6], ignore_index =True)

# %%
df.head()
# Out:
#    Epoch_time_s  milliseconds_elapsed        Ax        Ay        Az        Gx  \
# 0    1609459203                     0 -0.159668 -0.832031  0.364746 -2.793893
# 1    1609459203                   216 -0.215332 -0.874023  0.377441 -4.007634
# 2    1609459204                     0 -0.217285 -0.847656  0.352051 -6.106870
# 3    1609459204                   218 -0.147461 -0.847656  0.336426  3.435115
# 4    1609459204                   436 -0.168945 -0.840332  0.401367 -4.664122
#
#           Gy         Gz  Label
# 0   5.076336   6.748092    NaN
# 1   4.259542   3.259542    NaN
# 2   7.809160  -0.038168    NaN
# 3 -24.618320 -11.870230    NaN
# 4   2.351145  -1.633588    2.0

# %%
print(df)
# Out:
#       Epoch_time_s  milliseconds_elapsed        Ax        Ay        Az  \
# 0       1609459203                     0 -0.159668 -0.832031  0.364746
# 1       1609459203                   216 -0.215332 -0.874023  0.377441
# 2       1609459204                     0 -0.217285 -0.847656  0.352051
# 3       1609459204                   218 -0.147461 -0.847656  0.336426
# 4       1609459204                   436 -0.168945 -0.840332  0.401367
# ...            ...                   ...       ...       ...       ...
# 2836    1609459347                     0 -0.758301 -0.682617 -0.038574
# 2837    1609459347                   271 -0.801758 -0.599609 -0.052734
# 2838    1609459347                   575 -0.727051 -0.764648 -0.032227
# 2839    1609459347                   825 -0.556152 -0.768555  0.040039
# 2840    1609459348                     0 -0.306641 -0.905762  0.032715
#
#              Gx         Gy         Gz  Label
# 0     -2.793893   5.076336   6.748092    NaN
# ...

# %%
df = df.dropna(subset=['Label'])

# %%
df.reset_index(drop=True, inplace=True)

# %%
print(df)
# Out:
#       Epoch_time_s  milliseconds_elapsed        Ax        Ay        Az  \
# 0       1609459204                   436 -0.168945 -0.840332  0.401367
# 1       1609459204                   655 -0.136719 -0.843262  0.380371
# 2       1609459204                   876 -0.188477 -0.917969  0.445312
# 3       1609459205                     0 -0.425781 -0.498535  0.530273
# 4       1609459205                   259 -0.265625 -0.564453  0.548828
# ...            ...                   ...       ...       ...       ...
# 2830    1609459347                     0 -0.758301 -0.682617 -0.038574
# 2831    1609459347                   271 -0.801758 -0.599609 -0.052734
# 2832    1609459347                   575 -0.727051 -0.764648 -0.032227
# 2833    1609459347                   825 -0.556152 -0.768555  0.040039
# 2834    1609459348                     0 -0.306641 -0.905762  0.032715
#
#              Gx         Gy         Gz  Label
# 0     -4.664122   2.351145  -1.633588    2.0
# ...

# %%
print(fall3
     )
# Out:
#      Epoch_time_s  milliseconds_elapsed        Ax        Ay        Az  \
# 0      1609459203                     0  0.176269 -0.860352  0.120606
# 1      1609459203                   216  0.280762 -1.087402  0.024902
# 2      1609459204                     0  0.530762 -1.207520 -0.024414
# 3      1609459204                   218  0.447266 -0.956055 -0.002930
# 4      1609459204                   437  0.483887 -0.634277 -0.033691
# ..            ...                   ...       ...       ...       ...
# 292    1609459280                   510  0.286133 -0.835449  0.364258
# 293    1609459280                   767  0.136231 -0.805176  0.364258
# 294    1609459281                     0  0.156250 -0.878418  0.333984
# 295    1609459281                   312  0.434570 -0.987305 -0.018555
# 296    1609459281                   574  0.440430 -0.943848  0.007812
#
#             Gx         Gy         Gz  Label
# 0    -6.129771  14.274810 -38.328240      2
# ...

# %%
total_nan = df.isna().sum().sum()
print(f"Total NaN values in the entire DataFrame: {total_nan}")
# Out:
# Total NaN values in the entire DataFrame: 0

# %%
df = df.copy()
df['Label'] = df['Label'].apply(lambda x: 1 if x == 0 else 0)

# %%
df.to_csv('new_falldata.csv', index=False)

# %%
# Scatter plot for accelerometer and gyroscope for person 1
plt.figure(figsize=(12, 6))
plt.scatter(range(len(fall1['Ax'])), fall1['Ax'], label='Ax', color='red', s=10, alpha=0.7)
plt.scatter(range(len(fall1['Ay'])), fall1['Ay'], label='Ay', color='green', s=10, alpha=0.7)
plt.scatter(range(len(fall1['Az'])), fall1['Az'], label='Az', color='black', s=10, alpha=0.7)
plt.title('Accelerometer Data Points')
plt.xlabel('Index')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(12, 6))
plt.scatter(range(len(fall1['Gx'])), fall1['Gx'], label='Gx', color='red', s=10, alpha=0.7)
plt.scatter(range(len(fall1['Gy'])), fall1['Gy'], label='Gy', color='green', s=10, alpha=0.7)
plt.scatter(range(len(fall1['Gz'])), fall1['Gz'], label='Gz', color='black', s=10, alpha=0.7)
plt.title('Gyroscope Data Points')
plt.xlabel('Index')
plt.ylabel('Angular Velocity (deg/s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
data = df
#Line plot for accelerometer and gyroscope data 

plt.figure(figsize=(12, 6))
plt.plot(range(len(data['Ax'])), data['Ax'], label='Ax', color='red', linewidth=1.5, alpha=0.7)
plt.plot(range(len(data['Ay'])), data['Ay'], label='Ay', color='green', linewidth=1.5, alpha=0.7)
plt.plot(range(len(data['Az'])), data['Az'], label='Az', color='black', linewidth=1.5, alpha=0.7)
plt.title('Accelerometer Data Over Index')
plt.xlabel('Index')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(12, 6))
plt.plot(range(len(data['Gx'])), data['Gx'], label='Gx', color='red', linewidth=1.5, alpha=0.7)
plt.plot(range(len(data['Gy'])), data['Gy'], label='Gy', color='green', linewidth=1.5, alpha=0.7)
plt.plot(range(len(data['Gz'])), data['Gz'], label='Gz', color='black', linewidth=1.5, alpha=0.7)
plt.title('Gyroscope Data Over Index')
plt.xlabel('Index')
plt.ylabel('Angular Velocity (deg/s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
fall1['Label'] = fall1['Label'].apply(lambda x: 1 if x == 0 else 0)

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(len(fall1['Ax'])), fall1['Ax'], label='Ax', color='red', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Ay'])), fall1['Ay'], label='Ay', color='green', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Az'])), fall1['Az'], label='Az', color='black', linewidth=1.5, alpha=0.7)
plt.title('Accelerometer Data Over Index')
plt.xlabel('Index')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(len(fall1['Gx'])), fall1['Gx'], label='Gx', color='red', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Gy'])), fall1['Gy'], label='Gy', color='green', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Gz'])), fall1['Gz'], label='Gz', color='black', linewidth=1.5, alpha=0.7)
plt.title('Gyroscope Data Over Index')
plt.xlabel('Index')
plt.ylabel('Angular velocity (rad/sec)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(range(len(fall1['Ax'])), fall1['Ax'], label='Ax', color='red', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Ay'])), fall1['Ay'], label='Ay', color='green', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Az'])), fall1['Az'], label='Az', color='black', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Gx'])), fall1['Gx'], label='Gx', color='blue', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Gy'])), fall1['Gy'], label='Gy', color='orange', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Gz'])), fall1['Gz'], label='Gz', color='grey', linewidth=1.5, alpha=0.7)
plt.title('Accelerometer Data Over Index')
plt.xlabel('Index')
plt.ylabel('Acceleration (m/s^2)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Scaling data to a  range of [-10, 10] and [-20,20] for proper visualization
def scale(data, min_range, max_range):
    data_min = np.min(data)
    data_max = np.max(data)
    return ((data - data_min) / (data_max - data_min)) * (max_range - min_range) + min_range

# %%
# Scaling gyroscope data
fall1['Gx'] = scale(fall1['Gx'], -20, 20)
fall1['Gy'] = scale(fall1['Gy'], -20, 20)
fall1['Gz'] = scale(fall1['Gz'], -20, 20)

# %%
# Scaling accelerometer data
fall1['Ax'] = scale(fall1['Ax'], -10, 10)
fall1['Ay'] = scale(fall1['Ay'], -10, 10)
fall1['Az'] = scale(fall1['Az'], -10, 10)

# %%
# Plotting for Accelerometer and Gyroscope Data
plt.figure(figsize=(12, 6))

plt.plot(range(len(fall1['Gx'])), fall1['Gx'], label='Gx', color='red', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Gy'])), fall1['Gy'], label='Gy', color='green', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Gz'])), fall1['Gz'], label='Gz', color='black', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Ax'])), fall1['Ax'], label='Ax', color='blue', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Ay'])), fall1['Ay'], label='Ay', color='purple', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Az'])), fall1['Az'], label='Az', color='orange', linewidth=1.5, alpha=0.7)

# Highlighting regions for falls
for i in range(len(fall1['Label'])):
    if fall1['Label'][i] == 1:  # Occurance of Fall event
        plt.axvspan(i - 0.5, i + 0.5, color='orange', alpha=0.3)  # Highlighting the fall

plt.title('Scaled Accelerometer and Gyroscope Data with Fall Indications')
plt.xlabel('Index')
plt.ylabel('Scaled Value')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
fall1['Gx'] = scale(fall1['Gx'], -10, 10)
fall1['Gy'] = scale(fall1['Gy'], -10, 10)
fall1['Gz'] = scale(fall1['Gz'], -10, 10)
fall1['Ax'] = scale(fall1['Ax'], -10, 10)
fall1['Ay'] = scale(fall1['Ay'], -10, 10)
fall1['Az'] = scale(fall1['Az'], -10, 10)

# %%
# visualizing with same range for accelerometer and gyroscope data
plt.figure(figsize=(12, 6))

plt.plot(range(len(fall1['Gx'])), fall1['Gx'], label='Gx', color='red', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Gy'])), fall1['Gy'], label='Gy', color='green', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Gz'])), fall1['Gz'], label='Gz', color='black', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Ax'])), fall1['Ax'], label='Ax', color='blue', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Ay'])), fall1['Ay'], label='Ay', color='purple', linewidth=1.5, alpha=0.7)
plt.plot(range(len(fall1['Az'])), fall1['Az'], label='Az', color='orange', linewidth=1.5, alpha=0.7)


for i in range(len(fall1['Label'])):
    if fall1['Label'][i] == 1:  
        plt.axvspan(i - 0.5, i + 0.5, color='orange', alpha=0.3)  

plt.title('Scaled Accelerometer and Gyroscope Data with Fall Indications')
plt.xlabel('Index')
plt.ylabel('Scaled Value')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
